# %% [markdown]
# # python pandas tutorial part-15

# %% [markdown]
# ## pandas loc & iloc

# %%
import pandas as pd

# %%
df=pd.read_csv("lec_15.csv")
df
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 0         1001      10           2              9                        3
# 1         1002      10           6              8                        2
# 2         1003      10           3              8                        2
# 3         1004      11           0             10                        1
# 4         1005      11           4              7                        2
# 5         1006      11          10              7                        0
# 6         1007      12           4              6                        0
# 7         1008      12          10              6                        2
# 8         1009      12           2              8                        2
# 9         1010      12           6              9                        1
#
#    Mobile Games hrs   Percantege
# 0                  5          50
# 1                  0          80
# 2                  4          60
# ...

# %%
# df.loc[] #this gives the details about the given parameter

# %%
df.loc[0] #it will give details about first column
# Out:
# Student ID                 1001
# Class                        10
# Study hrs                     2
# Sleeping hrs                  9
# Social Media usage hrs        3
# Mobile Games hrs              5
# Percantege                   50
# Name: 0, dtype: int64

# %%
# we can give list, array or boolean or slice value to print multiple data

# %%
df.loc[[1,3]]
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 1         1002      10           6              8                        2
# 3         1004      11           0             10                        1
#
#    Mobile Games hrs   Percantege
# 1                  0          80
# 3                  5          45

# %%
df
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 0         1001      10           2              9                        3
# 1         1002      10           6              8                        2
# 2         1003      10           3              8                        2
# 3         1004      11           0             10                        1
# 4         1005      11           4              7                        2
# 5         1006      11          10              7                        0
# 6         1007      12           4              6                        0
# 7         1008      12          10              6                        2
# 8         1009      12           2              8                        2
# 9         1010      12           6              9                        1
#
#    Mobile Games hrs   Percantege
# 0                  5          50
# 1                  0          80
# 2                  4          60
# ...

# %%
    df.loc[4:'class']
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 4         1005      11           4              7                        2
# 5         1006      11          10              7                        0
# 6         1007      12           4              6                        0
# 7         1008      12          10              6                        2
# 8         1009      12           2              8                        2
# 9         1010      12           6              9                        1
#
#    Mobile Games hrs   Percantege
# 4                  0          75
# 5                  0          96
# 6                  0          80
# 7                  0          90
# 8                  4          60
# 9                  0          85

# %%
df.loc[[True, False, True,True, False, True,True, False, True,False]]
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 0         1001      10           2              9                        3
# 2         1003      10           3              8                        2
# 3         1004      11           0             10                        1
# 5         1006      11          10              7                        0
# 6         1007      12           4              6                        0
# 8         1009      12           2              8                        2
#
#    Mobile Games hrs   Percantege
# 0                  5          50
# 2                  4          60
# 3                  5          45
# 5                  0          96
# 6                  0          80
# 8                  4          60

# %%
df.loc[2:5]
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 2         1003      10           3              8                        2
# 3         1004      11           0             10                        1
# 4         1005      11           4              7                        2
# 5         1006      11          10              7                        0
#
#    Mobile Games hrs   Percantege
# 2                  4          60
# 3                  5          45
# 4                  0          75
# 5                  0          96

# %%
df.loc[2:5,'Percantege']
# Out:
# 2    60
# 3    45
# 4    75
# 5    96
# Name: Percantege, dtype: int64

# %%
# df.loc[[False,False,True]] # it returns boolean list as the same index as the same row

# %%
df.loc[df['Percantege']<70]
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 0         1001      10           2              9                        3
# 2         1003      10           3              8                        2
# 3         1004      11           0             10                        1
# 8         1009      12           2              8                        2
#
#    Mobile Games hrs   Percantege
# 0                  5          50
# 2                  4          60
# 3                  5          45
# 8                  4          60

# %%
# df.iloc[] ->integer bases  location

# %%
df
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 0         1001      10           2              9                        3
# 1         1002      10           6              8                        2
# 2         1003      10           3              8                        2
# 3         1004      11           0             10                        1
# 4         1005      11           4              7                        2
# 5         1006      11          10              7                        0
# 6         1007      12           4              6                        0
# 7         1008      12          10              6                        2
# 8         1009      12           2              8                        2
# 9         1010      12           6              9                        1
#
#    Mobile Games hrs   Percantege
# 0                  5          50
# 1                  0          80
# 2                  4          60
# ...

# %%
df.iloc[0]
# Out:
# Student ID                 1001
# Class                        10
# Study hrs                     2
# Sleeping hrs                  9
# Social Media usage hrs        3
# Mobile Games hrs              5
# Percantege                   50
# Name: 0, dtype: int64

# %%
df.iloc[2:5]
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 2         1003      10           3              8                        2
# 3         1004      11           0             10                        1
# 4         1005      11           4              7                        2
#
#    Mobile Games hrs   Percantege
# 2                  4          60
# 3                  5          45
# 4                  0          75

# %%
df.iloc[[0]]
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 0         1001      10           2              9                        3
#
#    Mobile Games hrs   Percantege
# 0                  5          50

# %%
df.iloc[:,0]
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# 5    1006
# 6    1007
# 7    1008
# 8    1009
# 9    1010
# Name: Student ID , dtype: int64

# %%
df.iloc[[3,7]]
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 3         1004      11           0             10                        1
# 7         1008      12          10              6                        2
#
#    Mobile Games hrs   Percantege
# 3                  5          45
# 7                  0          90

# %%
df.iloc[[True, False, True,True, False, True,True, False, True,False]]
# Out:
#    Student ID   Class   Study hrs   Sleeping hrs   Social Media usage hrs   \
# 0         1001      10           2              9                        3
# 2         1003      10           3              8                        2
# 3         1004      11           0             10                        1
# 5         1006      11          10              7                        0
# 6         1007      12           4              6                        0
# 8         1009      12           2              8                        2
#
#    Mobile Games hrs   Percantege
# 0                  5          50
# 2                  4          60
# 3                  5          45
# 5                  0          96
# 6                  0          80
# 8                  4          60
